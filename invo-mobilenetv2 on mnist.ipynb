# %% [markdown]
# # Libraries Import

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math
import datetime
import platform
import cv2
print('Python version:', platform.python_version())
print('Tensorflow version:', tf.__version__)
print('Keras version:', tf.keras.__version__)
import os
import h5py
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
import scipy.misc
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, ReLU, DepthwiseConv2D, add
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
# %matplotlib inline
import tensorflow.keras.backend as K
# Image dataset has channels as its last dimensions
K.set_image_data_format('channels_last')
# Out:
# Python version: 3.10.12
# Tensorflow version: 2.12.0
# Keras version: 2.12.0

# %% [markdown]
# #Data Preprocessing

# %%
mnist_dataset = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist_dataset.load_data()

print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)

# Save image parameters to the constants that we will use later for data re-shaping and for model traning.
input_shape = x_train.shape

IMAGE_CHANNELS = 1

# print('Number_of_elements:', Number_of_elements)
# print('IMAGE_WIDTH:', IMAGE_WIDTH)
# print('IMAGE_HEIGHT:', IMAGE_HEIGHT)
# print('IMAGE_CHANNELS:', IMAGE_CHANNELS)
x_train_normalized = x_train / 255
x_test_normalized = x_test / 255
print(input_shape)
print(x_train_normalized.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)
# (60000, 28, 28)
# (60000, 28, 28)

# %%
mnist_dataset = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist_dataset.load_data()

print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)

# Save image parameters to the constants that we will use later for data re-shaping and for model traning.
(Number_of_elements, IMAGE_WIDTH, IMAGE_HEIGHT) = x_train.shape
IMAGE_CHANNELS = 1

print('Number_of_elements:', Number_of_elements)
print('IMAGE_WIDTH:', IMAGE_WIDTH)
print('IMAGE_HEIGHT:', IMAGE_HEIGHT)
print('IMAGE_CHANNELS:', IMAGE_CHANNELS)
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)
# Number_of_elements: 60000
# IMAGE_WIDTH: 28
# IMAGE_HEIGHT: 28
# IMAGE_CHANNELS: 1

# %%
print('Initial x_train : ', x_train.shape) # (60000, 28, 28)
x_train = np.expand_dims(x_train, axis=-1)
x_train = tf.image.resize(x_train, [32,32])
print('Final x_train : ', x_train.shape) # (60000, 32, 32, 1)


print('Initial x_test : ', x_test.shape) # (60000, 28, 28)
x_test = np.expand_dims(x_test, axis=-1)
x_test = tf.image.resize(x_test, [32,32])
print('Final x_test : ' ,x_test.shape) # (60000, 32, 32, 1)
# Out:
# Initial x_train :  (60000, 28, 28)
# Final x_train :  (60000, 32, 32, 1)
# Initial x_test :  (10000, 28, 28)
# Final x_test :  (10000, 32, 32, 1)

# %%
x_train_normalized = x_train / 255
x_test_normalized = x_test / 255
x_train_normalized = np.repeat(x_train, 3, axis=3)
x_test_normalized = np.repeat(x_test, 3, axis=3)

# %%
print(x_train_normalized.shape)
print(x_test_normalized.shape)
# Out:
# (60000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# # Model Architecture (MobilenetV2)

# %%
import tensorflow as tf
class Involution(keras.layers.Layer):
    def __init__(
        self, channel, group_number, kernel_size, stride, reduction_ratio, name
    ):
        super().__init__(name=name)

        # Initialize the parameters.
        self.channel = channel
        self.group_number = group_number
        self.kernel_size = kernel_size
        self.stride = stride
        self.reduction_ratio = reduction_ratio

    def get_config(self):
     #   config = super().get_config()
        config=({
                  'channel': self.channel,
                  'group_number': self.group_number,
                  'reduction_ratio': self.reduction_ratio,
                  'kernel_size': self.kernel_size,
                  'stride': self.stride
                  })
        return config


    def build(self, input_shape):
        # Get the shape of the input.
        (_, height, width, num_channels) = input_shape

        # Scale the height and width with respect to the strides.
        height = height // self.stride
        width = width // self.stride

        # Define a layer that average pools the input tensor
        # if stride is more than 1.
        self.stride_layer = (
            keras.layers.AveragePooling2D(
                pool_size=self.stride, strides=self.stride, padding="same"
            )
            if self.stride > 1
            else tf.identity
        )
        # Define the kernel generation layer.
        self.kernel_gen = keras.Sequential(
            [
                keras.layers.Conv2D(
                    filters=self.channel // self.reduction_ratio, kernel_size=1
                ),
                keras.layers.BatchNormalization(),
                keras.layers.ReLU(),
                keras.layers.Conv2D(
                    filters=self.kernel_size * self.kernel_size * self.group_number,
                    kernel_size=1,
                ),
            ]
        )
        # Define reshape layers
        self.kernel_reshape = keras.layers.Reshape(
            target_shape=(
                height,
                width,
                self.kernel_size * self.kernel_size,
                1,
                self.group_number,
            )
        )
        self.input_patches_reshape = keras.layers.Reshape(
            target_shape=(
                height,
                width,
                self.kernel_size * self.kernel_size,
                num_channels // self.group_number,
                self.group_number,
            )
        )
        self.output_reshape = keras.layers.Reshape(
            target_shape=(height, width, num_channels)
        )

    def call(self, x):
        # Generate the kernel with respect to the input tensor.
        # B, H, W, K*K*G
        kernel_input = self.stride_layer(x)
        kernel = self.kernel_gen(kernel_input)

        # reshape the kerenl
        # B, H, W, K*K, 1, G
        kernel = self.kernel_reshape(kernel)

        # Extract input patches.
        # B, H, W, K*K*C
        input_patches = tf.image.extract_patches(
            images=x,
            sizes=[1, self.kernel_size, self.kernel_size, 1],
            strides=[1, self.stride, self.stride, 1],
            rates=[1, 1, 1, 1],
            padding="SAME",
        )

        # Reshape the input patches to align with later operations.
        # B, H, W, K*K, C//G, G
        input_patches = self.input_patches_reshape(input_patches)

        # Compute the multiply-add operation of kernels and patches.
        # B, H, W, K*K, C//G, G
        output = tf.multiply(kernel, input_patches)
        # B, H, W, C//G, G
        output = tf.reduce_sum(output, axis=3)

        # Reshape the output kernel.
        # B, H, W, C
        output = self.output_reshape(output)

        # Return the output tensor and the kernel.
        return output

# %%
def expansion_block(x,t,filters,stage,block_id):
    inv_name_base = 'res' + str(stage) + block_id + '_branch'
    bn_name_base = 'bn' + str(stage) + block_id + '_branch'
    prefix = 'block_{}_'.format(block_id)
    total_filters = t*filters
    stride =2
    x=Involution(channel=total_filters,group_number=1,kernel_size=1,stride=stride,reduction_ratio=1, name="inv_1_"+bn_name_base + '2a')(x)
    # x = Conv2D(total_filters,1,padding='same',use_bias=False, name = prefix +'expand')(x)
    x = BatchNormalization(name=prefix +'expand_bn')(x)
    x = ReLU(6,name = prefix +'expand_relu')(x)
    return x
def depthwise_block(x,stride,block_id):
    prefix = 'block_{}_'.format(block_id)
    x = DepthwiseConv2D(3,strides=(stride,stride),padding ='same', use_bias = False, name = prefix + 'depthwise_conv')(x)
    x = BatchNormalization(name=prefix +'dw_bn')(x)
    x = ReLU(6,name = prefix +'dw_relu')(x)
    return x
def projection_block(x,out_channels,block_id):
    prefix = 'block_{}_'.format(block_id)
    #x = Conv2D(filters=out_channels,kernel_size = 1,   padding='same',use_bias=False,name= prefix + 'compress')(x)
    x = BatchNormalization(name=prefix +'compress_bn')(x)
    return x

# %%
def Bottleneck(x,t,filters, out_channels,stage,stride,block_id):
    stage = block_id
    y = expansion_block(x,t,filters,stage,block_id)
    y = depthwise_block(y,stride,block_id)
    y = projection_block(y, out_channels,block_id)
    if y.shape[-1]==x.shape[-1]:
       y = add([x,y])
    return y

# %%
# input = Input (input_shape)
# x = Conv2D(32,3,strides=(2,2),padding='same', use_bias=False)(input)
# x = BatchNormalization(name='conv1_bn')(x)
# x = ReLU(6, name='conv1_relu')(x)

# %%
# x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 2)

# %%
# x = Conv2D(filters = 1280,kernel_size = 1,padding='same',use_bias=False, name = 'last_conv')(x)
# x = BatchNormalization(name='last_bn')(x)
# x = ReLU(6,name='last_relu')(x)
# x = GlobalAveragePooling2D(name='global_average_pool')(x)
# output = Dense(n_classes=10,activation='softmax')(x)

# %%
def MobileNetV2(input_image=(32,32,3), n_classes=10):
    input = Input (input_image)
    x=Involution(channel=64,group_number=1,kernel_size=7,stride=2,reduction_ratio=1, name="inv_0")(input)
    # x = Conv2D(32,3,strides=(2,2),padding='same', use_bias=False)(input)
    x = BatchNormalization(name='conv1_bn')(x)
    x = ReLU(6, name='conv1_relu')(x)
    # 17 Bottlenecks
    x = depthwise_block(x,stride=1,block_id=1)
    x = projection_block(x, out_channels=16,block_id=1)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 2)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 1,block_id = 3)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 2,block_id = 4)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 5)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 32, stride = 1,block_id = 6)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 2,block_id = 7)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 8)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 9)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 64, stride = 1,block_id = 10)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 11)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 12)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 96, stride = 1,block_id = 13)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 2,block_id = 14)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 15)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 160, stride = 1,block_id = 16)
    x = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 320, stride = 1,block_id = 17)
    x = Conv2D(filters = 1280,kernel_size = 1,padding='same',use_bias=False, name = 'last_conv')(x)
    x = BatchNormalization(name='last_bn')(x)
    x = ReLU(6,name='last_relu')(x)
    x = GlobalAveragePooling2D(name='global_average_pool')(x)
    output = Dense(n_classes,activation='softmax')(x)
    model = Model(input, output)
    return model

# %%
model = MobileNetV2(input_image=(32, 32, 3), n_classes=10)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  inv_0 (Involution)             (None, 16, 16, 3)    3697        ['input_1[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 3)    12          ['inv_0[0][0]']
#
#  conv1_relu (ReLU)              (None, 16, 16, 3)    0           ['conv1_bn[0][0]']
#
#  block_1_depthwise_conv (Depthw  (None, 16, 16, 3)   27          ['conv1_relu[0][0]']
#  iseConv2D)
#
#  block_1_dw_bn (BatchNormalizat  (None, 16, 16, 3)   12          ['block_1_depthwise_conv[0][0]']
#  ion)
#
#  block_1_dw_relu (ReLU)         (None, 16, 16, 3)    0           ['block_1_dw_bn[0][0]']
#
#  block_1_compress (Conv2D)      (None, 16, 16, 16)   48          ['block_1_dw_relu[0][0]']
#
#  block_1_compress_bn (BatchNorm  (None, 16, 16, 16)  64          ['block_1_compress[0][0]']
#  alization)
#
#  block_2_expand (Conv2D)        (None, 16, 16, 96)   1536        ['block_1_compress_bn[0][0]']
#
#  block_2_expand_bn (BatchNormal  (None, 16, 16, 96)  384         ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 16, 16, 96)   0           ['block_2_expand_bn[0][0]']
#
#  block_2_depthwise_conv (Depthw  (None, 8, 8, 96)    864         ['block_2_expand_relu[0][0]']
#  iseConv2D)
#
#  block_2_dw_bn (BatchNormalizat  (None, 8, 8, 96)    384         ['block_2_depthwise_conv[0][0]']
#  ion)
#
#  block_2_dw_relu (ReLU)         (None, 8, 8, 96)     0           ['block_2_dw_bn[0][0]']
#
#  block_2_compress (Conv2D)      (None, 8, 8, 24)     2304        ['block_2_dw_relu[0][0]']
#
#  block_2_compress_bn (BatchNorm  (None, 8, 8, 24)    96          ['block_2_compress[0][0]']
#  alization)
#
#  block_3_expand (Conv2D)        (None, 8, 8, 144)    3456        ['block_2_compress_bn[0][0]']
#
#  block_3_expand_bn (BatchNormal  (None, 8, 8, 144)   576         ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 8, 8, 144)    0           ['block_3_expand_bn[0][0]']
#
#  block_3_depthwise_conv (Depthw  (None, 8, 8, 144)   1296        ['block_3_expand_relu[0][0]']
#  iseConv2D)
#
#  block_3_dw_bn (BatchNormalizat  (None, 8, 8, 144)   576         ['block_3_depthwise_conv[0][0]']
#  ion)
#
#  block_3_dw_relu (ReLU)         (None, 8, 8, 144)    0           ['block_3_dw_bn[0][0]']
#
#  block_3_compress (Conv2D)      (None, 8, 8, 24)     3456        ['block_3_dw_relu[0][0]']
#
#  block_3_compress_bn (BatchNorm  (None, 8, 8, 24)    96          ['block_3_compress[0][0]']
#  alization)
#
#  add (Add)                      (None, 8, 8, 24)     0           ['block_2_compress_bn[0][0]',
#                                                                   'block_3_compress_bn[0][0]']
#
#  block_4_expand (Conv2D)        (None, 8, 8, 144)    3456        ['add[0][0]']
#
#  block_4_expand_bn (BatchNormal  (None, 8, 8, 144)   576         ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 8, 8, 144)    0           ['block_4_expand_bn[0][0]']
#
#  block_4_depthwise_conv (Depthw  (None, 4, 4, 144)   1296        ['block_4_expand_relu[0][0]']
#  iseConv2D)
#
#  block_4_dw_bn (BatchNormalizat  (None, 4, 4, 144)   576         ['block_4_depthwise_conv[0][0]']
#  ion)
#
#  block_4_dw_relu (ReLU)         (None, 4, 4, 144)    0           ['block_4_dw_bn[0][0]']
#
#  block_4_compress (Conv2D)      (None, 4, 4, 32)     4608        ['block_4_dw_relu[0][0]']
#
#  block_4_compress_bn (BatchNorm  (None, 4, 4, 32)    128         ['block_4_compress[0][0]']
#  alization)
#
#  block_5_expand (Conv2D)        (None, 4, 4, 192)    6144        ['block_4_compress_bn[0][0]']
#
#  block_5_expand_bn (BatchNormal  (None, 4, 4, 192)   768         ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 4, 4, 192)    0           ['block_5_expand_bn[0][0]']
#
#  block_5_depthwise_conv (Depthw  (None, 4, 4, 192)   1728        ['block_5_expand_relu[0][0]']
#  iseConv2D)
#
#  block_5_dw_bn (BatchNormalizat  (None, 4, 4, 192)   768         ['block_5_depthwise_conv[0][0]']
#  ion)
#
#  block_5_dw_relu (ReLU)         (None, 4, 4, 192)    0           ['block_5_dw_bn[0][0]']
#
#  block_5_compress (Conv2D)      (None, 4, 4, 32)     6144        ['block_5_dw_relu[0][0]']
#
#  block_5_compress_bn (BatchNorm  (None, 4, 4, 32)    128         ['block_5_compress[0][0]']
#  alization)
#
#  add_1 (Add)                    (None, 4, 4, 32)     0           ['block_4_compress_bn[0][0]',
#                                                                   'block_5_compress_bn[0][0]']
#
#  block_6_expand (Conv2D)        (None, 4, 4, 192)    6144        ['add_1[0][0]']
#
#  block_6_expand_bn (BatchNormal  (None, 4, 4, 192)   768         ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 4, 4, 192)    0           ['block_6_expand_bn[0][0]']
#
#  block_6_depthwise_conv (Depthw  (None, 4, 4, 192)   1728        ['block_6_expand_relu[0][0]']
#  iseConv2D)
#
#  block_6_dw_bn (BatchNormalizat  (None, 4, 4, 192)   768         ['block_6_depthwise_conv[0][0]']
#  ion)
#
#  block_6_dw_relu (ReLU)         (None, 4, 4, 192)    0           ['block_6_dw_bn[0][0]']
#
#  block_6_compress (Conv2D)      (None, 4, 4, 32)     6144        ['block_6_dw_relu[0][0]']
#
#  block_6_compress_bn (BatchNorm  (None, 4, 4, 32)    128         ['block_6_compress[0][0]']
#  alization)
#
#  add_2 (Add)                    (None, 4, 4, 32)     0           ['add_1[0][0]',
#                                                                   'block_6_compress_bn[0][0]']
#
#  block_7_expand (Conv2D)        (None, 4, 4, 192)    6144        ['add_2[0][0]']
#
#  block_7_expand_bn (BatchNormal  (None, 4, 4, 192)   768         ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 4, 4, 192)    0           ['block_7_expand_bn[0][0]']
#
#  block_7_depthwise_conv (Depthw  (None, 2, 2, 192)   1728        ['block_7_expand_relu[0][0]']
#  iseConv2D)
#
#  block_7_dw_bn (BatchNormalizat  (None, 2, 2, 192)   768         ['block_7_depthwise_conv[0][0]']
#  ion)
#
#  block_7_dw_relu (ReLU)         (None, 2, 2, 192)    0           ['block_7_dw_bn[0][0]']
#
#  block_7_compress (Conv2D)      (None, 2, 2, 64)     12288       ['block_7_dw_relu[0][0]']
#
#  block_7_compress_bn (BatchNorm  (None, 2, 2, 64)    256         ['block_7_compress[0][0]']
#  alization)
#
#  block_8_expand (Conv2D)        (None, 2, 2, 384)    24576       ['block_7_compress_bn[0][0]']
#
#  block_8_expand_bn (BatchNormal  (None, 2, 2, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 2, 2, 384)    0           ['block_8_expand_bn[0][0]']
#
#  block_8_depthwise_conv (Depthw  (None, 2, 2, 384)   3456        ['block_8_expand_relu[0][0]']
#  iseConv2D)
#
#  block_8_dw_bn (BatchNormalizat  (None, 2, 2, 384)   1536        ['block_8_depthwise_conv[0][0]']
#  ion)
#
#  block_8_dw_relu (ReLU)         (None, 2, 2, 384)    0           ['block_8_dw_bn[0][0]']
#
#  block_8_compress (Conv2D)      (None, 2, 2, 64)     24576       ['block_8_dw_relu[0][0]']
#
#  block_8_compress_bn (BatchNorm  (None, 2, 2, 64)    256         ['block_8_compress[0][0]']
#  alization)
#
#  add_3 (Add)                    (None, 2, 2, 64)     0           ['block_7_compress_bn[0][0]',
#                                                                   'block_8_compress_bn[0][0]']
#
#  block_9_expand (Conv2D)        (None, 2, 2, 384)    24576       ['add_3[0][0]']
#
#  block_9_expand_bn (BatchNormal  (None, 2, 2, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 2, 2, 384)    0           ['block_9_expand_bn[0][0]']
#
#  block_9_depthwise_conv (Depthw  (None, 2, 2, 384)   3456        ['block_9_expand_relu[0][0]']
#  iseConv2D)
#
#  block_9_dw_bn (BatchNormalizat  (None, 2, 2, 384)   1536        ['block_9_depthwise_conv[0][0]']
#  ion)
#
#  block_9_dw_relu (ReLU)         (None, 2, 2, 384)    0           ['block_9_dw_bn[0][0]']
#
#  block_9_compress (Conv2D)      (None, 2, 2, 64)     24576       ['block_9_dw_relu[0][0]']
#
#  block_9_compress_bn (BatchNorm  (None, 2, 2, 64)    256         ['block_9_compress[0][0]']
#  alization)
#
#  add_4 (Add)                    (None, 2, 2, 64)     0           ['add_3[0][0]',
#                                                                   'block_9_compress_bn[0][0]']
#
#  block_10_expand (Conv2D)       (None, 2, 2, 384)    24576       ['add_4[0][0]']
#
#  block_10_expand_bn (BatchNorma  (None, 2, 2, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 2, 2, 384)    0           ['block_10_expand_bn[0][0]']
#
#  block_10_depthwise_conv (Depth  (None, 2, 2, 384)   3456        ['block_10_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_10_dw_bn (BatchNormaliza  (None, 2, 2, 384)   1536        ['block_10_depthwise_conv[0][0]']
#  tion)
#
#  block_10_dw_relu (ReLU)        (None, 2, 2, 384)    0           ['block_10_dw_bn[0][0]']
#
#  block_10_compress (Conv2D)     (None, 2, 2, 64)     24576       ['block_10_dw_relu[0][0]']
#
#  block_10_compress_bn (BatchNor  (None, 2, 2, 64)    256         ['block_10_compress[0][0]']
#  malization)
#
#  add_5 (Add)                    (None, 2, 2, 64)     0           ['add_4[0][0]',
#                                                                   'block_10_compress_bn[0][0]']
#
#  block_11_expand (Conv2D)       (None, 2, 2, 384)    24576       ['add_5[0][0]']
#
#  block_11_expand_bn (BatchNorma  (None, 2, 2, 384)   1536        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 2, 2, 384)    0           ['block_11_expand_bn[0][0]']
#
#  block_11_depthwise_conv (Depth  (None, 2, 2, 384)   3456        ['block_11_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_11_dw_bn (BatchNormaliza  (None, 2, 2, 384)   1536        ['block_11_depthwise_conv[0][0]']
#  tion)
#
#  block_11_dw_relu (ReLU)        (None, 2, 2, 384)    0           ['block_11_dw_bn[0][0]']
#
#  block_11_compress (Conv2D)     (None, 2, 2, 96)     36864       ['block_11_dw_relu[0][0]']
#
#  block_11_compress_bn (BatchNor  (None, 2, 2, 96)    384         ['block_11_compress[0][0]']
#  malization)
#
#  block_12_expand (Conv2D)       (None, 2, 2, 576)    55296       ['block_11_compress_bn[0][0]']
#
#  block_12_expand_bn (BatchNorma  (None, 2, 2, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 2, 2, 576)    0           ['block_12_expand_bn[0][0]']
#
#  block_12_depthwise_conv (Depth  (None, 2, 2, 576)   5184        ['block_12_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_12_dw_bn (BatchNormaliza  (None, 2, 2, 576)   2304        ['block_12_depthwise_conv[0][0]']
#  tion)
#
#  block_12_dw_relu (ReLU)        (None, 2, 2, 576)    0           ['block_12_dw_bn[0][0]']
#
#  block_12_compress (Conv2D)     (None, 2, 2, 96)     55296       ['block_12_dw_relu[0][0]']
#
#  block_12_compress_bn (BatchNor  (None, 2, 2, 96)    384         ['block_12_compress[0][0]']
#  malization)
#
#  add_6 (Add)                    (None, 2, 2, 96)     0           ['block_11_compress_bn[0][0]',
#                                                                   'block_12_compress_bn[0][0]']
#
#  block_13_expand (Conv2D)       (None, 2, 2, 576)    55296       ['add_6[0][0]']
#
#  block_13_expand_bn (BatchNorma  (None, 2, 2, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 2, 2, 576)    0           ['block_13_expand_bn[0][0]']
#
#  block_13_depthwise_conv (Depth  (None, 2, 2, 576)   5184        ['block_13_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_13_dw_bn (BatchNormaliza  (None, 2, 2, 576)   2304        ['block_13_depthwise_conv[0][0]']
#  tion)
#
#  block_13_dw_relu (ReLU)        (None, 2, 2, 576)    0           ['block_13_dw_bn[0][0]']
#
#  block_13_compress (Conv2D)     (None, 2, 2, 96)     55296       ['block_13_dw_relu[0][0]']
#
#  block_13_compress_bn (BatchNor  (None, 2, 2, 96)    384         ['block_13_compress[0][0]']
#  malization)
#
#  add_7 (Add)                    (None, 2, 2, 96)     0           ['add_6[0][0]',
#                                                                   'block_13_compress_bn[0][0]']
#
#  block_14_expand (Conv2D)       (None, 2, 2, 576)    55296       ['add_7[0][0]']
#
#  block_14_expand_bn (BatchNorma  (None, 2, 2, 576)   2304        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 2, 2, 576)    0           ['block_14_expand_bn[0][0]']
#
#  block_14_depthwise_conv (Depth  (None, 1, 1, 576)   5184        ['block_14_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_14_dw_bn (BatchNormaliza  (None, 1, 1, 576)   2304        ['block_14_depthwise_conv[0][0]']
#  tion)
#
#  block_14_dw_relu (ReLU)        (None, 1, 1, 576)    0           ['block_14_dw_bn[0][0]']
#
#  block_14_compress (Conv2D)     (None, 1, 1, 160)    92160       ['block_14_dw_relu[0][0]']
#
#  block_14_compress_bn (BatchNor  (None, 1, 1, 160)   640         ['block_14_compress[0][0]']
#  malization)
#
#  block_15_expand (Conv2D)       (None, 1, 1, 960)    153600      ['block_14_compress_bn[0][0]']
#
#  block_15_expand_bn (BatchNorma  (None, 1, 1, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 1, 1, 960)    0           ['block_15_expand_bn[0][0]']
#
#  block_15_depthwise_conv (Depth  (None, 1, 1, 960)   8640        ['block_15_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_15_dw_bn (BatchNormaliza  (None, 1, 1, 960)   3840        ['block_15_depthwise_conv[0][0]']
#  tion)
#
#  block_15_dw_relu (ReLU)        (None, 1, 1, 960)    0           ['block_15_dw_bn[0][0]']
#
#  block_15_compress (Conv2D)     (None, 1, 1, 160)    153600      ['block_15_dw_relu[0][0]']
#
#  block_15_compress_bn (BatchNor  (None, 1, 1, 160)   640         ['block_15_compress[0][0]']
#  malization)
#
#  add_8 (Add)                    (None, 1, 1, 160)    0           ['block_14_compress_bn[0][0]',
#                                                                   'block_15_compress_bn[0][0]']
#
#  block_16_expand (Conv2D)       (None, 1, 1, 960)    153600      ['add_8[0][0]']
#
#  block_16_expand_bn (BatchNorma  (None, 1, 1, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 1, 1, 960)    0           ['block_16_expand_bn[0][0]']
#
#  block_16_depthwise_conv (Depth  (None, 1, 1, 960)   8640        ['block_16_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_16_dw_bn (BatchNormaliza  (None, 1, 1, 960)   3840        ['block_16_depthwise_conv[0][0]']
#  tion)
#
#  block_16_dw_relu (ReLU)        (None, 1, 1, 960)    0           ['block_16_dw_bn[0][0]']
#
#  block_16_compress (Conv2D)     (None, 1, 1, 160)    153600      ['block_16_dw_relu[0][0]']
#
#  block_16_compress_bn (BatchNor  (None, 1, 1, 160)   640         ['block_16_compress[0][0]']
#  malization)
#
#  add_9 (Add)                    (None, 1, 1, 160)    0           ['add_8[0][0]',
#                                                                   'block_16_compress_bn[0][0]']
#
#  block_17_expand (Conv2D)       (None, 1, 1, 960)    153600      ['add_9[0][0]']
#
#  block_17_expand_bn (BatchNorma  (None, 1, 1, 960)   3840        ['block_17_expand[0][0]']
#  lization)
#
#  block_17_expand_relu (ReLU)    (None, 1, 1, 960)    0           ['block_17_expand_bn[0][0]']
#
#  block_17_depthwise_conv (Depth  (None, 1, 1, 960)   8640        ['block_17_expand_relu[0][0]']
#  wiseConv2D)
#
#  block_17_dw_bn (BatchNormaliza  (None, 1, 1, 960)   3840        ['block_17_depthwise_conv[0][0]']
#  tion)
#
#  block_17_dw_relu (ReLU)        (None, 1, 1, 960)    0           ['block_17_dw_bn[0][0]']
#
#  block_17_compress (Conv2D)     (None, 1, 1, 320)    307200      ['block_17_dw_relu[0][0]']
#
#  block_17_compress_bn (BatchNor  (None, 1, 1, 320)   1280        ['block_17_compress[0][0]']
#  malization)
#
#  last_conv (Conv2D)             (None, 1, 1, 1280)   409600      ['block_17_compress_bn[0][0]']
#
#  last_bn (BatchNormalization)   (None, 1, 1, 1280)   5120        ['last_conv[0][0]']
#
#  last_relu (ReLU)               (None, 1, 1, 1280)   0           ['last_bn[0][0]']
#
#  global_average_pool (GlobalAve  (None, 1280)        0           ['last_relu[0][0]']
#  ragePooling2D)
#
#  dense (Dense)                  (None, 10)           12810       ['global_average_pool[0][0]']
#
# ==================================================================================================
# Total params: 2,272,670
# Trainable params: 2,238,546
# Non-trainable params: 34,124
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

model.compile(
    optimizer=adam_optimizer,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)

# %%
training_history = model.fit(x_train_normalized,
     y_train,
     epochs=50,
     batch_size = 256,
     validation_data=(x_test_normalized, y_test),
 )

# %% [markdown]
# # Evaluation

# %%
import matplotlib.pyplot as plt

print('min Test loss: ', min(training_history.history['val_loss']))
print('max Test accuracy: ', max( training_history.history['val_accuracy']))

# summarize history for accuracy
plt.plot(training_history.history['accuracy'])
plt.plot(training_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(training_history.history['loss'])
plt.plot(training_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
